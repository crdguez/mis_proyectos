# %% [markdown]
# ## Geometría con Sympy y Python

# %% [markdown]
# * Averigua el punto simétrico de $A(5, -1)$ con respecto a $B(4, -2)$.

# %%
from sympy.geometry import Point, Line
from sympy import pi, latex, symbols, solve
x, y, z, t = symbols('x y z t')
p1, p2 = Point(5,-1), Point(4,-2)
p3=p1.rotate(pi,p2)
p3
# Out:
# Point2D(3, -3)

# %%
p1.midpoint(p3)
# Out:
# Point2D(4, -2)

# %%
p1.midpoint(p2)
# Out:
# Point2D(9/2, -3/2)

# %% [markdown]
# * Dados los puntos $A(2, -3)$, $B(-1, 4)$ y $C(x, 3)$, determina el valor de x para que $A$, $B$ y $C$ estén alineados.

# %%
p1, p2 = Point(2,-3), Point(-1,4)
y3=3
l1=Line(p1,p2)
l1.direction.y
solve((y3-p2.y)/l1.direction.y-(x-p2.x)/l1.direction.x)
# Out:
# [-4/7]

# %%
p3= Point(-4/7,3)
p1.is_collinear(p2,p3)
# Out:
# True

# %% [markdown]
# * Halla las coordenadas del vértice $D$ del paralelogramo $ABCD$, sabiendo que $A(-1, -2)$, $B(3, 1)$ y $C(1, 3)$.

# %%
A, B, C, D = Point(-1,-2), Point(3,1), Point(1,3), Point
D=C-Line(A,B).direction
D
# Out:
# Point2D(-3, 0)

# %% [markdown]
# * Sea un paralelogramo $ABCD$. Si $A(2,3)$, $B(5,1)$ y $C(4,0)$, halla

# %%
A, B, C, D = Point(2,3), Point(5,1), Point(4,0), Point
D=C-Line(A,B).direction
D
l1=Line(A,B)
l1.equation()
# Out:
# 2*x + 3*y - 13

# %% [markdown]
# * Calcula la distancia que hay entre los puntos
# $A(8,10)$ y $B(-2,14)$

# %%
A, B = Point(8,10), Point(-2,14)
A.distance(B)
# Out:
# 2*sqrt(29)

# %% [markdown]
# * Halla las ecuaciones paramétricas de la recta paralela a $2x - y + 3 = 0 $ y que pasa por el punto $P(4, 3)$.

# %%
P = Point(4,3)
l1 = Line(Point(0,3),Point(-3/2,0))
l2 = Line (P,P+l1.direction)
print(l2.equation())
print(l2.arbitrary_point())
# Out:
# 3*x - 3*y/2 - 15/2
# Point2D(-3*t/2 + 4, -3*t + 3)

# %% [markdown]
# * Dadas las rectas:  $r \equiv \left\{
#     {\begin{matrix}
# 	   {x = 2 - 4\lambda }  \\
# 	   {y =  - 2 + \lambda}  \\
#     \end{matrix} } \right.$ 	y
#     $s \equiv \left\{ {\begin{matrix}
#    {x = 3 + 8\lambda }  \\
#    {y =  - 1 - 2\lambda }  \\
# \end{matrix} } \right.$  averigua su posición relativa. Si se cortan, di cuál es el punto de corte

# %%
P1, V1, P2, V2 = Point(2,-2), Point(-4,1), Point(3,-1), Point(8,-2)
r = Line(P1, P1+V1)
print(r.direction)
s = Line(P2, P2+V2)
print(s.direction)
print(r.is_parallel(s))
r.intersection(s)
# Out:
# Point2D(-4, 1)
# Point2D(8, -2)
# True
# []

# %% [markdown]
# * Dados los puntos A(-1, -1), B(1, 4) y C(5, 2), hallar:
# Si están alineados

# %% [markdown]
# Si están alineados

# %%
A, B, C = Point(-1,-1), Point(1,4), Point(5,2)
A.is_collinear(B,C)
# Out:
# False

# %% [markdown]
# Mediana desde B

# %%
M1=A.midpoint(C)
M=Line(M1,B)
M1, M.equation()
# Out:
# (Point2D(2, 1/2), -7*x/2 - y + 15/2)

# %% [markdown]
# Altura desde A

# %%
l1=Line(B,C)
l2=l1.perpendicular_line(A)
l1.equation(), l2.equation()
# Out:
# (2*x + 4*y - 18, -4*x + 2*y - 2)

# %% [markdown]
# Mediatriz del lado AB

# %%
M1=A.midpoint(C)
l1 = Line(A,B)
l2 = l1.perpendicular_line(M1)
l1.equation(), l2.equation()
# Out:
# (-5*x + 2*y - 3, -2*x - 5*y + 13/2)

# %% [markdown]
# * Sean $A(1,0)$, $B(4,-3)$ y $C(5,2)$ los tres vértices de un triángulo. Hallar:

# %% [markdown]
# La ecuación de la recta que pasando por A es paralela a la que pasa por B y C

# %%
A, B, C = Point(1,0), Point(4,-3), Point(5,2)
A.is_collinear(B,C)
l1 = Line(B,C)
l2 = l1.parallel_line(A)
l1.equation(), l2.equation()
# Out:
# (-5*x + y + 23, -5*x + y + 5)

# %% [markdown]
# La ecuación de la mediana que pasa por C.

# %%
M1=A.midpoint(B)
M=Line(M1,C)
M1, M.equation()
# Out:
# (Point2D(5/2, -3/2), -7*x/2 + 5*y/2 + 25/2)

# %%
'''This example is only interesting when ran in interactive mode'''

import matplotlib.pyplot as plt
import numpy as np

# Plot circle or radius 3

an = np.linspace(0, 2*np.pi, 100)

plt.subplot(221)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.title('not equal, looks like ellipse', fontsize=10)

plt.subplot(222)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.title('equal, looks like circle', fontsize=10)

plt.subplot(223)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.title('looks like circle, even after changing limits', fontsize=10)

plt.subplot(224)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.plot([0, 4], [0, 4])
plt.title('still equal after adding line', fontsize=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import sympy as sy
#from sympy import symbols, plot_implicit, Eq

# %matplotlib notebook

x, y = sy.symbols('x y')
p1 = plot_implicit(sy.Eq(x**2 +y**2, 4))
fg, ax = p1._backend.fig, p1._backend.ax  # get matplotib's figure and ax

# Use matplotlib to change appearance: 
ax.axis('equal')  # list of float or {‘on’, ‘off’, ‘equal’, ‘tight’, ‘scaled’, ‘normal’, ‘auto’, ‘image’, ‘square’}
#ax.set_aspect("equal") # 'auto', 'equal' or a positive integer is allowed
#ax.grid(True)
#fg.canvas.draw()


p1.show()  # enter matplotlib's event loop (not needed in Jupyter)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sympy import *

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
#fig = hp._backend.fig
ax = hp._backend.ax
#xx = yy = np.linspace(-3,3)
#ax.plot(xx,yy) # y = x
ax.plot([0],[0],'o') # Point (0,0)
ax.set_aspect('equal','datalim')

#fig.canvas.draw()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sympy import symbols, Eq
#from sympy.plotting import plot, plot_implicit
import matplotlib.pyplot as p1

x, y = symbols('x y')
p1.plot(x*x, show=False)
#p1 = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3), show=False)
#p1.set_aspect('equal')
p1.axis('equal')
#p2 = plot(x)
#p1.extend(p2)
p1.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d50f0095f741> in <module>()
#       4
#       5 x, y = symbols('x y')
# ----> 6 p1.plot(x*x, show=False)
#       7 #p1 = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3), show=False)
#       8 #p1.set_aspect('equal')
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3238                       mplDeprecation)
#    3239     try:
# -> 3240         ret = ax.plot(*args, **kwargs)
#    3241     finally:
#    3242         ax._hold = washold
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1708                     warnings.warn(msg % (label_namer, func.__name__),
#    1709                                   RuntimeWarning, stacklevel=2)
# -> 1710             return func(ax, *args, **kwargs)
#    1711         pre_doc = inner.__doc__
#    1712         if pre_doc is None:
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1435         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1436
# -> 1437         for line in self._get_lines(*args, **kwargs):
#    1438             self.add_line(line)
#    1439             lines.append(line)
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     402                 this += args[0],
#     403                 args = args[1:]
# --> 404             for seg in self._plot_args(this, kwargs):
#     405                 yield seg
#     406
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     392         ncx, ncy = x.shape[1], y.shape[1]
#     393         for j in xrange(max(ncx, ncy)):
# --> 394             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     395             ret.append(seg)
#     396         return ret
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     299         default_dict = self._getdefaults(None, kw)
#     300         self._setdefaults(default_dict, kw)
# --> 301         seg = mlines.Line2D(x, y, **kw)
#     302         return seg
#     303
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     424         # update kwargs before updating data to give the caller a
#     425         # chance to init axes (and hence unit support)
# --> 426         self.update(kwargs)
#     427         self.pickradius = pickradius
#     428         self.ind_offset = 0
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     845         try:
#     846             ret = [_update_property(self, k, v)
# --> 847                    for k, v in props.items()]
#     848         finally:
#     849             self.eventson = store
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     845         try:
#     846             ret = [_update_property(self, k, v)
# --> 847                    for k, v in props.items()]
#     848         finally:
#     849             self.eventson = store
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     838                 func = getattr(self, 'set_' + k, None)
#     839                 if not callable(func):
# --> 840                     raise AttributeError('Unknown property %s' % k)
#     841                 return func(v)
#     842
#
# AttributeError: Unknown property show

# %%
plot(x**2, adaptive=True, nb_of_points=3)

# %%
import matplotlib.pyplot as plt
import numpy as np
an = np.linspace(0, 2*np.pi, 100)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.title('equal, looks like circle', fontsize=10)
plt.show()

# %%
#https://stackoverflow.com/questions/40747474/sympy-and-plotting

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sympy import *

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
fig = hp._backend.fig
ax = hp._backend.ax
xx = yy = np.linspace(-3,3)
ax.plot(xx,yy) # y = x
ax.plot([0],[0],'o') # Point (0,0)
ax.set_aspect('equal','datalim')
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
