# %% [markdown]
# ## Geometría con Sympy y Python

# %% [markdown]
# * Averigua el punto simétrico de $A(5, -1)$ con respecto a $B(4, -2)$.

# %%
from sympy.geometry import Point, Line
from sympy import pi, latex, symbols, solve, plot_implicit
x, y, z, t = symbols('x y z t')
p1, p2 = Point(5,-1), Point(4,-2)
p3=p1.rotate(pi,p2)
p3
# Out:
# Point2D(3, -3)

# %% [markdown]
# ### Función que aleatoriamente calcula el simétrico de uno dado respecto al otro

# %%
from sympy import *
from sympy import latex
from random import randint

def simetrico(rango=5):
    m1, m2, b1, b2 = randint(-1*rango, rango), randint(-1*rango, rango), randint(-1*rango, rango), randint(-1*rango, rango)
    A, M = Point(m1, m2), Point(b1, b2)
    print(A, M)
    B = A.rotate(pi,M)
    print (str(A)+" "+str(M),B)
    return str(A)+" "+str(M), B 

simetrico()
# Out:
# Point2D(2, -4) Point2D(0, 4)
# Point2D(2, -4) Point2D(0, 4) Point2D(-2, 12)
# ('Point2D(2, -4) Point2D(0, 4)', Point2D(-2, 12))

# %%
print(p1, p3)
p1.midpoint(p3)
# Out:
# Point2D(5, -1) Point2D(3, -3)
# Point2D(4, -2)

# %%
p1.midpoint(p2)
# Out:
# Point2D(9/2, -3/2)

# %% [markdown]
# * Dados los puntos $A(2, -3)$, $B(-1, 4)$ y $C(x, 3)$, determina el valor de x para que $A$, $B$ y $C$ estén alineados.

# %%
p1, p2 = Point(2,-3), Point(-1,4)
y3=3
l1=Line(p1,p2)
l1.direction.y
solve((y3-p2.y)/l1.direction.y-(x-p2.x)/l1.direction.x)
# Out:
# [-4/7]

# %%
p3= Point(-4/7,3)
p1.is_collinear(p2,p3)
# Out:
# True

# %% [markdown]
# * Halla las coordenadas del vértice $D$ del paralelogramo $ABCD$, sabiendo que $A(-1, -2)$, $B(3, 1)$ y $C(1, 3)$.

# %%
A, B, C, D = Point(-1,-2), Point(3,1), Point(1,3), Point
D=C-Line(A,B).direction
D
# Out:
# Point2D(-3, 0)

# %% [markdown]
# * Sea un paralelogramo $ABCD$. Si $A(2,3)$, $B(5,1)$ y $C(4,0)$, halla

# %%
A, B, C, D = Point(2,3), Point(5,1), Point(4,0), Point
D=C-Line(A,B).direction
D
l1=Line(A,B)
l1.equation()
# Out:
# 2*x + 3*y - 13

# %% [markdown]
# * Calcula la distancia que hay entre los puntos
# $A(8,10)$ y $B(-2,14)$

# %%
from sympy import *

A, B = Point(8,10), Point(-2,14)
print(latex(A.distance(B)))
A.distance(B)
# Out:
# 2 \sqrt{29}
# 2*sqrt(29)

# %%
from sympy import *

A, B = Point(8,10), Point(3,-2)
print(latex(A.distance(B)))
A.distance(B)
# Out:
# 13
# 13

# %% [markdown]
# * Halla las ecuaciones paramétricas de la recta paralela a $2x - y + 3 = 0 $ y que pasa por el punto $P(4, 3)$.

# %%
P = Point(4,3)
l1 = Line(Point(0,3),Point(-3/2,0))
l2 = Line (P,P+l1.direction)
print(l2.equation())
print(l2.arbitrary_point())

# %matplotlib notebook
p = plot_implicit(l2.equation())
p1 = plot_implicit(l1.equation())

p.extend(p1)

p._backend.ax.set_aspect('equal')
p.show()
# Out:
# 3*x - 3*y/2 - 15/2
# Point2D(-3*t/2 + 4, -3*t + 3)
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# * Dadas las rectas:  $r \equiv \left\{
#     {\begin{matrix}
# 	   {x = 2 - 4\lambda }  \\
# 	   {y =  - 2 + \lambda}  \\
#     \end{matrix} } \right.$ 	y
#     $s \equiv \left\{ {\begin{matrix}
#    {x = 3 + 8\lambda }  \\
#    {y =  - 1 - 2\lambda }  \\
# \end{matrix} } \right.$  averigua su posición relativa. Si se cortan, di cuál es el punto de corte

# %%
P1, V1, P2, V2 = Point(2,-2), Point(-4,1), Point(3,-1), Point(8,-2)
r = Line(P1, P1+V1)
print(r.direction)
s = Line(P2, P2+V2)
print(s.direction)
print(r.is_parallel(s))
r.intersection(s)
# Out:
# Point2D(-4, 1)
# Point2D(8, -2)
# True
# []

# %% [markdown]
# * Dados los puntos A(-1, -1), B(1, 4) y C(5, 2), hallar:
# Si están alineados

# %% [markdown]
# Si están alineados

# %%
A, B, C = Point(-1,-1), Point(1,4), Point(5,2)
A.is_collinear(B,C)
# Out:
# False

# %% [markdown]
# Mediana desde B

# %%
M1=A.midpoint(C)
M=Line(M1,B)
M1, M.equation()
# Out:
# (Point2D(2, 1/2), -7*x/2 - y + 15/2)

# %% [markdown]
# Altura desde A

# %%
l1=Line(B,C)
l2=l1.perpendicular_line(A)
l1.equation(), l2.equation()
# Out:
# (2*x + 4*y - 18, -4*x + 2*y - 2)

# %% [markdown]
# Mediatriz del lado AB

# %%
M1=A.midpoint(C)
l1 = Line(A,B)
l2 = l1.perpendicular_line(M1)
l1.equation(), l2.equation()
# Out:
# (-5*x + 2*y - 3, -2*x - 5*y + 13/2)

# %% [markdown]
# * Sean $A(1,0)$, $B(4,-3)$ y $C(5,2)$ los tres vértices de un triángulo. Hallar:

# %% [markdown]
# La ecuación de la recta que pasando por A es paralela a la que pasa por B y C

# %%
A, B, C = Point(1,0), Point(4,-3), Point(5,2)
A.is_collinear(B,C)
l1 = Line(B,C)
l2 = l1.parallel_line(A)
l1.equation(), l2.equation()
# Out:
# (-5*x + y + 23, -5*x + y + 5)

# %% [markdown]
# La ecuación de la mediana que pasa por C.

# %%
M1=A.midpoint(B)
M=Line(M1,C)
M1, M.equation()
# Out:
# (Point2D(5/2, -3/2), -7*x/2 + 5*y/2 + 25/2)

# %%
'''This example is only interesting when ran in interactive mode'''

import matplotlib.pyplot as plt
import numpy as np

# Plot circle or radius 3

an = np.linspace(0, 2*np.pi, 100)

plt.subplot(221)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.title('not equal, looks like ellipse', fontsize=10)

plt.subplot(222)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.title('equal, looks like circle', fontsize=10)

plt.subplot(223)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.title('looks like circle, even after changing limits', fontsize=10)

plt.subplot(224)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.plot([0, 4], [0, 4])
plt.title('still equal after adding line', fontsize=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
an = np.linspace(0, 2*np.pi, 100)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.title('equal, looks like circle', fontsize=10)
plt.show()

# %%
#https://stackoverflow.com/questions/40747474/sympy-and-plotting

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sympy import *

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
fig = hp._backend.fig
ax = hp._backend.ax
xx = yy = np.linspace(-3,3)
ax.plot(xx,yy) # y = x
ax.plot([0],[0],'o') # Point (0,0)
ax.set_aspect('equal','datalim')
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## En el triángulo de vértices $A(-3,1)$, $B(1,5)$ y $C(4,0)$, halla:

# %% [markdown]
# La ecuación de la recta h sobre la que se apoya la altura trazada desde el vértice B.

# %%
from sympy import S
A, B, C = Point(-3,1), Point(1,5), Point(4,0)
r = Line(A,C)
s = r.perpendicular_line(B)
P = next(iter(r.intersect(s)))
r.equation(), r.direction, s.equation(), s.direction, P
# Out:
# (x + 7*y - 4,
#  Point2D(7, -1),
#  -7*x + y + 2,
#  Point2D(1, 7),
#  Point2D(9/25, 13/25))

# %% [markdown]
# La ecuación de la mediatriz m del lado AB.

# %%
t = Line(A,B)
m = t.perpendicular_line(A.midpoint(B))
A.midpoint(B), t.direction, m.equation()
# Out:
# (Point2D(-1, 3), Point2D(4, 4), -4*x - 4*y + 8)

# %%
#altura que pasa por c, recta AB, corte de altura con base, altura, área

Line(A,B).perpendicular_line(C).equation(), Line(A,B).equation(), \
Line(A,B).intersect(Line(A,B).perpendicular_line(C)), \
C.distance(next(iter(Line(A,B).intersect(Line(A,B).perpendicular_line(C))))), \
A.distance(B)*C.distance(next(iter(Line(A,B).intersect(Line(A,B).perpendicular_line(C)))))/2
# Out:
# (-4*x - 4*y + 16, -4*x + 4*y - 16, {Point2D(0, 4)}, 4*sqrt(2), 16)

# %% [markdown]
#  El perímetro y el área del triángulo.

# %%
B.distance(P), A.distance(P), A.distance(B), sqrt(B.distance(P)**2 +  A.distance(P)**2), A.distance(C)
# Out:
# (16*sqrt(2)/5, 12*sqrt(2)/5, 4*sqrt(2), 4*sqrt(2), 5*sqrt(2))

# %%
perimetro = A.distance(B) + A.distance(C) + B.distance(C)
A.distance(B), A.distance(C), B.distance(C), perimetro, float(perimetro)
# Out:
# (4*sqrt(2), 5*sqrt(2), sqrt(34), sqrt(34) + 9*sqrt(2), 18.558873956203158)

# %%
area = A.distance(C) * B.distance(P) / 2
A.distance(C), B.distance(P), area
# Out:
# (5*sqrt(2), 16*sqrt(2)/5, 16)

# %% [markdown]
# El ańgulo del vértice $A$ ($\hat{A})$.

# %%
#float(deg(atan((16*sqrt(2)/5)/(12*sqrt(2)/5))))
float(deg(atan((B.distance(P))/(A.distance(P)))))
# Out:
# 53.13010235415598

# %% [markdown]
# ## Escribe la ecuación vectorial, paramétrica, continua, general y explícita de la recta que pasa por el punto $P(2,0)$ y tiene por vector direccional a $\overrightarrow{v}=[\overrightarrow{CD}]$, siendo $C(2,2)$ y $D(1,0)$

# %%
P,C,D = Point(2,0), Point(2,2), Point(1,0)

Line(C,D).direction, Line(P,P + Line(C,D).direction).equation(), Line(P,P + Line(C,D).direction).arbitrary_point()
# Out:
# (Point2D(-1, -2), 2*x - y - 4, Point2D(-t + 2, -2*t))

# %% [markdown]
# ## Sea un paralelogramo $ABCD$ (los vértices van en sentido de las agujas del reloj ). Si $A(2,3)$, $B(5,1)$ y $C(3,0)$, halla
# * El vértice $D$
# * El perímetro del paralelogramo
# * El área del paralelogramo

# %%
A, B, C = Point(2,3), Point(5,1), Point(3,0)

D = C - B + A

P = next(iter(Line(D,C).intersect(Line(D,C).perpendicular_line(A))))
P.distance(A)*D.distance(C)

D, A.distance(B), B.distance(C), C.distance(D), D.distance(A), \
    float(A.distance(B) + B.distance(C) + C.distance(D) + D.distance(A)), \
    P, D.distance(C), P.distance(A), P.distance(A)*D.distance(C)
# Out:
# (Point2D(0, 2),
#  sqrt(13),
#  sqrt(5),
#  sqrt(13),
#  sqrt(5),
#  11.683238505927559,
#  Point2D(12/13, 18/13),
#  sqrt(13),
#  7*sqrt(13)/13,
#  7)
