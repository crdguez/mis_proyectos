# %%
from sympy import *
x = symbols('x')
plot(x**2, adaptive=True, nb_of_points=3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot circle or radius 3

an = np.linspace(0, 2*np.pi, 100)

plt.subplot(221)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.title('not equal, looks like ellipse', fontsize=10)

plt.subplot(222)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.title('equal, looks like circle', fontsize=10)

plt.subplot(223)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.title('looks like circle, even after changing limits', fontsize=10)

plt.subplot(224)
plt.plot(3*np.cos(an), 3*np.sin(an))
plt.axis('equal')
plt.axis([-3, 3, -3, 3])
plt.plot([0, 4], [0, 4])
plt.title('still equal after adding line', fontsize=10)



plt.show()

# %%
#https://stackoverflow.com/questions/40747474/sympy-and-plotting

import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from sympy import *

x, y = symbols("x y")
hp = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
fig = hp._backend.fig
ax = hp._backend.ax
xx = yy = np.linspace(-3,3)
ax.plot(xx,yy) # y = x
ax.plot([0],[0],'o') # Point (0,0)
ax.set_aspect('equal','datalim')
fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
from sympy import *
# %matplotlib notebook
x, y = symbols("x y")
p = plot_implicit(Eq(x**2 + y**2, 4), (x, -3, 3), (y, -3, 3))
p._backend.ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
p6 = plot_implicit(And(y > x**2))
p7 = plot_implicit(Eq(y, 2*x+3))
p6.extend(p7)
p6.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
from sympy import plot_implicit
# ?plot_implicit

# %%
from sympy import plot_implicit, cos, sin, symbols, Eq, And
x, y = symbols('x y')


#p1 = plot_implicit(Eq(x**2 + y**2, 5))
p1 = plot_implicit(x**2 + y**2-5, show=False)
p2 = plot_implicit(y-x-1, show=False)
p1.extend(p2)

# %matplotlib notebook
p1.show()
p1._backend.ax.set_aspect('equal')
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
from sympy import *
from random import randint

rad_max = 3
m1, m2, b1, b2 = (randint(1,rad_max)), (randint(1,rad_max)), (randint(1,rad_max)), (randint(1,rad_max)) 

M, B = Point(m1, m2), Point(b1, b2)

A = M + (M - B)

print(A, M, B)

print(expand(Line(A,B).equation()))
print(latex(expand(Line(A,B).equation())))
print(expand(Circle(A,M.distance(B)).equation()))

p1 = plot_implicit(Line(A,B).equation(), title='Prueba', xlabel='Prueba2', show=False)
p1.extend(plot_implicit(Circle(M,M.distance(B)).equation(), show=False)) 
p1.extend(plot_implicit(Circle(A,0.1).equation(), show=False)) 
p1.extend(plot_implicit(Circle(B,0.1).equation(),  show=False)) 


# %matplotlib notebook
p1.show()
p1._backend.ax.set_aspect('equal')

latex(Line(A,B).equation()), latex(expand(Circle(A,M.distance(B)).equation()))
# Out:
# (Point2D(1, -1), Point2D(2, 1), Point2D(3, 3))
# -4*x + 2*y + 6
# - 4 x + 2 y + 6
# x**2 - 2*x + y**2 + 2*y - 3
# <img src="data:image/png;base64,..." width="639.85">
# ('- 4 x + 2 y + 6', 'x^{2} - 2 x + y^{2} + 2 y - 3')

# %%
a = Integral(x, (x, 1, 2))
s = Eq(a, a.doit())
latex(s)
# Out:
# '\\int_{1}^{2} x\\, dx = \\frac{3}{2}'

# %%
from sympy import init_session

init_session()
# Out:
# ---------------------------------------------------------------------------
# MultipleInstanceError                     Traceback (most recent call last)
# <ipython-input-4-d5dbd75a125b> in <module>()
#       1 from sympy import init_session
#       2
# ----> 3 init_session()
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/sympy/interactive/session.py in init_session(ipython, pretty_print, order, use_unicode, use_latex, quiet, auto_symbols, auto_int_to_Integer, str_printer, pretty_printer, latex_printer, argv)
#     431     else:
#     432         ip = init_ipython_session(argv=argv, auto_symbols=auto_symbols,
# --> 433             auto_int_to_Integer=auto_int_to_Integer)
#     434
#     435         if V(IPython.__version__) >= '0.11':
#
# ~/Mis_aplicaciones/anaconda3/lib/python3.6/site-packages/sympy/interactive/session.py in init_ipython_session(argv, auto_symbols, auto_int_to_Integer)
#     262         # don't draw IPython banner during initialization:
# ...

# %%
# inicializando

from __future__ import division
from sympy import *
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)

# %%
plot((x**2, (x, -6, 6)), (x, (x, -5, 5)))
