# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import numpy as np

# Enable inline plotting
# %matplotlib inline

# %%
print('Python version ' + sys.version)
print('Pandas version ' + pd.__version__)
print('Matplotlib version ' + matplotlib.__version__)
# Out:
# Python version 3.6.3 |Anaconda custom (64-bit)| (default, Oct 13 2017, 12:02:49)
# [GCC 7.2.0]
# Pandas version 0.22.0
# Matplotlib version 2.2.2

# %%
# pre_actilla = pd.read_csv('importado.csv', index_col = 0)
pre_actilla = pd.read_csv('importado.csv', index_col=False)
pre_actilla
# Out:
#      N                  Apellidos,Nombre  ARE  BG   CC  EF  FQ  Unnamed: 7  \
# 0    1       Alvar Hernández, José Darío  NaN   8  NaN   5   6         NaN
# 1    2           Amador Bolea, Alejandro  NaN   8  NaN   6   7         NaN
# 2    3              Amador Bolea, Álvaro  NaN   7  NaN   5   4         NaN
# 3    4             Arnillas Gómez, Lucía  9.0   6  NaN   5   4         NaN
# 4    5                 Asso Pino, Lorién  NaN   9  8.0   5   7         NaN
# 5    6            Bernal Bandrés, Chaime  9.0   9  NaN   5   8         NaN
# 6    7             Campos Bueno, Natalia  NaN   5  7.0   5   5         NaN
# 7    8        Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4         NaN
# 8    9         Cremallet Aguillo, Andrea  NaN  10  NaN   6   4         NaN
# 9   10             Diaconu , Diana María  NaN   6  NaN   6   4         NaN
# 10  11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3         NaN
# 11  12           González Blanco, Javier  9.0   9  NaN   7   9         NaN
# 12  13            González Blanco, Marta  9.0   6  NaN   5   4         NaN
# 13  14             Gracia Bardají, Sofía  NaN   7  NaN   5   3         NaN
# 14  15             Gracia Gonzalvo, Alba  NaN   6  NaN   5   2         NaN
# 15  16             Julián Pérez, Claudia  NaN   5  NaN   5   5         NaN
# 16  17           Lafuente García, Alexia  9.0   7  NaN   5   7         NaN
# 17  18           Mariscal Beltrán, Lucía  NaN   6  NaN   5   4         NaN
# 18  19         Martos Arévalo, Alejandro  NaN   8  NaN   5   5         NaN
# 19  20            Pallarés Arnau, Adrián  NaN   7  5.0   6   5         NaN
# 20  21             Parra Oblanca, Daniel  NaN  10  NaN   7   7         NaN
# 21  22               Pérez Herrer, David  NaN   7  NaN   7   7         NaN
# 22  23           Pino Fernández, Claudia  9.0   7  NaN   5   5         NaN
# 23  24            Rivas Gracia, Cristina  NaN   4  5.0   4   3         NaN
# 24  25             Santiago Calvo, María  NaN   6  NaN   4   2         NaN
# 25  26             Vera Blánquez, Andrea  9.0   7  NaN   5   4         NaN
# 26  27  Villalba Carroquino, Irene Pilar  9.0  10  NaN   8   9         NaN
#
#     FR2  GH     ...       MC   MU    RC  TIC   VET  Unnamed: 17  Unnamed: 18  \
# 0   7.0   8     ...        6  NaN   NaN  9.0   9.0            1          NaN
# 1   6.0   8     ...        8  NaN   NaN  9.0   9.0            0          NaN
# 2   7.0   7     ...        5  NaN   NaN  9.0   6.0            1          NaN
# 3   6.0   8     ...        3  NaN   8.0  NaN   NaN            3          NaN
# 4   8.0   9     ...        8  NaN   NaN  NaN   9.0            0          NaN
# 5   8.0   8     ...        9  NaN   NaN  NaN   8.0            0          NaN
# 6   5.0   8     ...        7  NaN   8.0  NaN   NaN            0          NaN
# 7   7.0   5     ...        3  NaN   9.0  NaN   NaN            4          NaN
# 8   8.0   7     ...        9  NaN   8.0  8.0   NaN            1          NaN
# 9   6.0   5     ...        5  NaN   NaN  8.0   6.0            2          NaN
# 10  5.0   7     ...        4  NaN   9.0  NaN   NaN            2          NaN
# 11  7.0   9     ...        9  NaN   NaN  NaN   9.0            0          NaN
# 12  6.0   6     ...        7  NaN   NaN  NaN   8.0            1          NaN
# 13  6.0   7     ...        4  NaN   NaN  5.0   7.0            3          NaN
# 14  6.0   6     ...        4  NaN   NaN  5.0   9.0            3          NaN
# 15  NaN   6     ...        6  9.0   8.0  7.0   NaN            1          NaN
# 16  6.0   7     ...        6  NaN   9.0  NaN   NaN            0          NaN
# 17  6.0   7     ...        6  NaN   NaN  8.0   6.0            1          NaN
# 18  NaN   8     ...        6  8.0   NaN  8.0   8.0            0          NaN
# 19  6.0   6     ...        5  NaN   7.0  NaN   NaN            1          NaN
# 20  8.0   9     ...        8  NaN   NaN  9.0   8.0            0          NaN
# 21  8.0   9     ...        9  NaN   NaN  9.0   7.0            0          NaN
# 22  NaN   7     ...        5  9.0   NaN  NaN  10.0            0          NaN
# 23  4.0   2     ...        2  NaN   7.0  NaN   NaN            8          NaN
# 24  7.0   2     ...        6  NaN   7.0  7.0   NaN            4          NaN
# 25  7.0   7     ...        4  NaN  10.0  NaN   NaN            3          NaN
# 26  9.0   9     ...        9  NaN   NaN  NaN  10.0            0          NaN
#
#     Unnamed: 19  Unnamed: 20  Unnamed: 21
# 0           NaN          NaN          NaN
# 1           NaN          NaN          NaN
# 2           NaN          NaN          NaN
# 3           NaN          NaN          NaN
# 4           NaN          NaN          NaN
# 5           NaN          NaN          NaN
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
# 11          NaN          NaN          NaN
# 12          NaN          NaN          NaN
# 13          NaN          NaN          NaN
# 14          NaN          NaN          NaN
# 15          NaN          NaN          NaN
# 16          NaN          NaN          NaN
# 17          NaN          NaN          NaN
# 18          NaN          NaN          NaN
# 19          NaN          NaN          NaN
# 20          NaN          NaN          NaN
# 21          NaN          NaN          NaN
# 22          NaN          NaN          NaN
# 23          NaN          NaN          NaN
# 24          NaN          NaN          NaN
# 25          NaN          NaN          NaN
# 26          NaN          NaN          NaN
#
# [27 rows x 22 columns]

# %%
#pd.read_csv?

# %%
filter_col = [col for col in pre_actilla if col.startswith('Unna')]
filter_col
# Out:
# ['Unnamed: 7',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21']

# %%
pre_actilla.drop([col for col in pre_actilla if col.startswith('Unna')], axis=1)
# Out:
#      N                  Apellidos,Nombre  ARE  BG   CC  EF  FQ  FR2  GH  IN  \
# 0    1       Alvar Hernández, José Darío  NaN   8  NaN   5   6  7.0   8   7
# 1    2           Amador Bolea, Alejandro  NaN   8  NaN   6   7  6.0   8   7
# 2    3              Amador Bolea, Álvaro  NaN   7  NaN   5   4  7.0   7   7
# 3    4             Arnillas Gómez, Lucía  9.0   6  NaN   5   4  6.0   8   6
# 4    5                 Asso Pino, Lorién  NaN   9  8.0   5   7  8.0   9   9
# 5    6            Bernal Bandrés, Chaime  9.0   9  NaN   5   8  8.0   8   9
# 6    7             Campos Bueno, Natalia  NaN   5  7.0   5   5  5.0   8   5
# 7    8        Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4  7.0   5   6
# 8    9         Cremallet Aguillo, Andrea  NaN  10  NaN   6   4  8.0   7   9
# 9   10             Diaconu , Diana María  NaN   6  NaN   6   4  6.0   5   7
# 10  11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3  5.0   7   6
# 11  12           González Blanco, Javier  9.0   9  NaN   7   9  7.0   9   9
# 12  13            González Blanco, Marta  9.0   6  NaN   5   4  6.0   6   6
# 13  14             Gracia Bardají, Sofía  NaN   7  NaN   5   3  6.0   7   5
# 14  15             Gracia Gonzalvo, Alba  NaN   6  NaN   5   2  6.0   6   7
# 15  16             Julián Pérez, Claudia  NaN   5  NaN   5   5  NaN   6   6
# 16  17           Lafuente García, Alexia  9.0   7  NaN   5   7  6.0   7   6
# 17  18           Mariscal Beltrán, Lucía  NaN   6  NaN   5   4  6.0   7   6
# 18  19         Martos Arévalo, Alejandro  NaN   8  NaN   5   5  NaN   8   6
# 19  20            Pallarés Arnau, Adrián  NaN   7  5.0   6   5  6.0   6   5
# 20  21             Parra Oblanca, Daniel  NaN  10  NaN   7   7  8.0   9   8
# 21  22               Pérez Herrer, David  NaN   7  NaN   7   7  8.0   9   9
# 22  23           Pino Fernández, Claudia  9.0   7  NaN   5   5  NaN   7   8
# 23  24            Rivas Gracia, Cristina  NaN   4  5.0   4   3  4.0   2   4
# 24  25             Santiago Calvo, María  NaN   6  NaN   4   2  7.0   2   7
# 25  26             Vera Blánquez, Andrea  9.0   7  NaN   5   4  7.0   7   8
# 26  27  Villalba Carroquino, Irene Pilar  9.0  10  NaN   8   9  9.0   9  10
#
#     LE  MC   MU    RC  TIC   VET
# 0    4   6  NaN   NaN  9.0   9.0
# 1    5   8  NaN   NaN  9.0   9.0
# 2    5   5  NaN   NaN  9.0   6.0
# 3    4   3  NaN   8.0  NaN   NaN
# 4    7   8  NaN   NaN  NaN   9.0
# 5    7   9  NaN   NaN  NaN   8.0
# 6    6   7  NaN   8.0  NaN   NaN
# 7    4   3  NaN   9.0  NaN   NaN
# 8    7   9  NaN   8.0  8.0   NaN
# 9    4   5  NaN   NaN  8.0   6.0
# 10   5   4  NaN   9.0  NaN   NaN
# 11   6   9  NaN   NaN  NaN   9.0
# 12   6   7  NaN   NaN  NaN   8.0
# 13   4   4  NaN   NaN  5.0   7.0
# 14   4   4  NaN   NaN  5.0   9.0
# 15   3   6  9.0   8.0  7.0   NaN
# 16   5   6  NaN   9.0  NaN   NaN
# 17   6   6  NaN   NaN  8.0   6.0
# 18   6   6  8.0   NaN  8.0   8.0
# 19   4   5  NaN   7.0  NaN   NaN
# 20   7   8  NaN   NaN  9.0   8.0
# 21   6   9  NaN   NaN  9.0   7.0
# 22   5   5  9.0   NaN  NaN  10.0
# 23   2   2  NaN   7.0  NaN   NaN
# 24   4   6  NaN   7.0  7.0   NaN
# 25   4   4  NaN  10.0  NaN   NaN
# 26   7   9  NaN   NaN  NaN  10.0

# %%
actilla = pre_actilla.loc[:, ~pre_actilla.columns.str.contains('^Unnamed')]

actilla
# Out:
#      N                  Apellidos,Nombre  ARE  BG   CC  EF  FQ  FR2  GH  IN  \
# 0    1       Alvar Hernández, José Darío  NaN   8  NaN   5   6  7.0   8   7
# 1    2           Amador Bolea, Alejandro  NaN   8  NaN   6   7  6.0   8   7
# 2    3              Amador Bolea, Álvaro  NaN   7  NaN   5   4  7.0   7   7
# 3    4             Arnillas Gómez, Lucía  9.0   6  NaN   5   4  6.0   8   6
# 4    5                 Asso Pino, Lorién  NaN   9  8.0   5   7  8.0   9   9
# 5    6            Bernal Bandrés, Chaime  9.0   9  NaN   5   8  8.0   8   9
# 6    7             Campos Bueno, Natalia  NaN   5  7.0   5   5  5.0   8   5
# 7    8        Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4  7.0   5   6
# 8    9         Cremallet Aguillo, Andrea  NaN  10  NaN   6   4  8.0   7   9
# 9   10             Diaconu , Diana María  NaN   6  NaN   6   4  6.0   5   7
# 10  11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3  5.0   7   6
# 11  12           González Blanco, Javier  9.0   9  NaN   7   9  7.0   9   9
# 12  13            González Blanco, Marta  9.0   6  NaN   5   4  6.0   6   6
# 13  14             Gracia Bardají, Sofía  NaN   7  NaN   5   3  6.0   7   5
# 14  15             Gracia Gonzalvo, Alba  NaN   6  NaN   5   2  6.0   6   7
# 15  16             Julián Pérez, Claudia  NaN   5  NaN   5   5  NaN   6   6
# 16  17           Lafuente García, Alexia  9.0   7  NaN   5   7  6.0   7   6
# 17  18           Mariscal Beltrán, Lucía  NaN   6  NaN   5   4  6.0   7   6
# 18  19         Martos Arévalo, Alejandro  NaN   8  NaN   5   5  NaN   8   6
# 19  20            Pallarés Arnau, Adrián  NaN   7  5.0   6   5  6.0   6   5
# 20  21             Parra Oblanca, Daniel  NaN  10  NaN   7   7  8.0   9   8
# 21  22               Pérez Herrer, David  NaN   7  NaN   7   7  8.0   9   9
# 22  23           Pino Fernández, Claudia  9.0   7  NaN   5   5  NaN   7   8
# 23  24            Rivas Gracia, Cristina  NaN   4  5.0   4   3  4.0   2   4
# 24  25             Santiago Calvo, María  NaN   6  NaN   4   2  7.0   2   7
# 25  26             Vera Blánquez, Andrea  9.0   7  NaN   5   4  7.0   7   8
# 26  27  Villalba Carroquino, Irene Pilar  9.0  10  NaN   8   9  9.0   9  10
#
#     LE  MC   MU    RC  TIC   VET
# 0    4   6  NaN   NaN  9.0   9.0
# 1    5   8  NaN   NaN  9.0   9.0
# 2    5   5  NaN   NaN  9.0   6.0
# 3    4   3  NaN   8.0  NaN   NaN
# 4    7   8  NaN   NaN  NaN   9.0
# 5    7   9  NaN   NaN  NaN   8.0
# 6    6   7  NaN   8.0  NaN   NaN
# 7    4   3  NaN   9.0  NaN   NaN
# 8    7   9  NaN   8.0  8.0   NaN
# 9    4   5  NaN   NaN  8.0   6.0
# 10   5   4  NaN   9.0  NaN   NaN
# 11   6   9  NaN   NaN  NaN   9.0
# 12   6   7  NaN   NaN  NaN   8.0
# 13   4   4  NaN   NaN  5.0   7.0
# 14   4   4  NaN   NaN  5.0   9.0
# 15   3   6  9.0   8.0  7.0   NaN
# 16   5   6  NaN   9.0  NaN   NaN
# 17   6   6  NaN   NaN  8.0   6.0
# 18   6   6  8.0   NaN  8.0   8.0
# 19   4   5  NaN   7.0  NaN   NaN
# 20   7   8  NaN   NaN  9.0   8.0
# 21   6   9  NaN   NaN  9.0   7.0
# 22   5   5  9.0   NaN  NaN  10.0
# 23   2   2  NaN   7.0  NaN   NaN
# 24   4   6  NaN   7.0  7.0   NaN
# 25   4   4  NaN  10.0  NaN   NaN
# 26   7   9  NaN   NaN  NaN  10.0

# %%
actilla.stack()
# Out:
# 0   N                                                  1
#     Apellidos,Nombre         Alvar Hernández, José Darío
#     BG                                                 8
#     EF                                                 5
#     FQ                                                 6
#     FR2                                                7
#     GH                                                 8
#     IN                                                 7
#     LE                                                 4
#     MC                                                 6
#     TIC                                                9
#     VET                                                9
# 1   N                                                  2
#     Apellidos,Nombre             Amador Bolea, Alejandro
#     BG                                                 8
#     EF                                                 6
#     FQ                                                 7
#     FR2                                                6
#     GH                                                 8
#     IN                                                 7
#     LE                                                 5
#     MC                                                 8
#     TIC                                                9
#     VET                                                9
# 2   N                                                  3
#     Apellidos,Nombre                Amador Bolea, Álvaro
#     BG                                                 7
#     EF                                                 5
#     FQ                                                 4
#     FR2                                                7
#                                       ...
# 24  GH                                                 2
#     IN                                                 7
#     LE                                                 4
#     MC                                                 6
#     RC                                                 7
#     TIC                                                7
# 25  N                                                 26
#     Apellidos,Nombre               Vera Blánquez, Andrea
#     ARE                                                9
#     BG                                                 7
#     EF                                                 5
#     FQ                                                 4
#     FR2                                                7
#     GH                                                 7
#     IN                                                 8
#     LE                                                 4
#     MC                                                 4
#     RC                                                10
# 26  N                                                 27
#     Apellidos,Nombre    Villalba Carroquino, Irene Pilar
#     ARE                                                9
#     BG                                                10
#     EF                                                 8
#     FQ                                                 9
#     FR2                                                9
#     GH                                                 9
#     IN                                                10
#     LE                                                 7
#     MC                                                 9
#     VET                                               10
# Length: 324, dtype: object

# %%
# pd.melt(actilla, id_vars=["N","Apellidos,Nombre"], var_name="Asignatura", value_name="Nota")
actilla2 = pd.melt(actilla, id_vars=["N","Apellidos,Nombre"], var_name="Asignatura", value_name="Nota")

# %%
i = 1
actilla3 = actilla2[actilla2['Nota'].notna()]
actilla3
# Out:
#       N                  Apellidos,Nombre Asignatura  Nota
# 3     4             Arnillas Gómez, Lucía        ARE   9.0
# 5     6            Bernal Bandrés, Chaime        ARE   9.0
# 7     8        Cárdenas Vaillant, Adriana        ARE   9.0
# 10   11            Gabelas Verdugo, Laura        ARE   9.0
# 11   12           González Blanco, Javier        ARE   9.0
# 12   13            González Blanco, Marta        ARE   9.0
# 16   17           Lafuente García, Alexia        ARE   9.0
# 22   23           Pino Fernández, Claudia        ARE   9.0
# 25   26             Vera Blánquez, Andrea        ARE   9.0
# 26   27  Villalba Carroquino, Irene Pilar        ARE   9.0
# 27    1       Alvar Hernández, José Darío         BG   8.0
# 28    2           Amador Bolea, Alejandro         BG   8.0
# 29    3              Amador Bolea, Álvaro         BG   7.0
# 30    4             Arnillas Gómez, Lucía         BG   6.0
# 31    5                 Asso Pino, Lorién         BG   9.0
# 32    6            Bernal Bandrés, Chaime         BG   9.0
# 33    7             Campos Bueno, Natalia         BG   5.0
# 34    8        Cárdenas Vaillant, Adriana         BG   5.0
# 35    9         Cremallet Aguillo, Andrea         BG  10.0
# 36   10             Diaconu , Diana María         BG   6.0
# 37   11            Gabelas Verdugo, Laura         BG   6.0
# 38   12           González Blanco, Javier         BG   9.0
# 39   13            González Blanco, Marta         BG   6.0
# 40   14             Gracia Bardají, Sofía         BG   7.0
# 41   15             Gracia Gonzalvo, Alba         BG   6.0
# 42   16             Julián Pérez, Claudia         BG   5.0
# 43   17           Lafuente García, Alexia         BG   7.0
# 44   18           Mariscal Beltrán, Lucía         BG   6.0
# 45   19         Martos Arévalo, Alejandro         BG   8.0
# 46   20            Pallarés Arnau, Adrián         BG   7.0
# ..   ..                               ...        ...   ...
# 322  26             Vera Blánquez, Andrea         RC  10.0
# 324   1       Alvar Hernández, José Darío        TIC   9.0
# 325   2           Amador Bolea, Alejandro        TIC   9.0
# 326   3              Amador Bolea, Álvaro        TIC   9.0
# 332   9         Cremallet Aguillo, Andrea        TIC   8.0
# 333  10             Diaconu , Diana María        TIC   8.0
# 337  14             Gracia Bardají, Sofía        TIC   5.0
# 338  15             Gracia Gonzalvo, Alba        TIC   5.0
# 339  16             Julián Pérez, Claudia        TIC   7.0
# 341  18           Mariscal Beltrán, Lucía        TIC   8.0
# 342  19         Martos Arévalo, Alejandro        TIC   8.0
# 344  21             Parra Oblanca, Daniel        TIC   9.0
# 345  22               Pérez Herrer, David        TIC   9.0
# 348  25             Santiago Calvo, María        TIC   7.0
# 351   1       Alvar Hernández, José Darío        VET   9.0
# 352   2           Amador Bolea, Alejandro        VET   9.0
# 353   3              Amador Bolea, Álvaro        VET   6.0
# 355   5                 Asso Pino, Lorién        VET   9.0
# 356   6            Bernal Bandrés, Chaime        VET   8.0
# 360  10             Diaconu , Diana María        VET   6.0
# 362  12           González Blanco, Javier        VET   9.0
# 363  13            González Blanco, Marta        VET   8.0
# 364  14             Gracia Bardají, Sofía        VET   7.0
# 365  15             Gracia Gonzalvo, Alba        VET   9.0
# 368  18           Mariscal Beltrán, Lucía        VET   6.0
# 369  19         Martos Arévalo, Alejandro        VET   8.0
# 371  21             Parra Oblanca, Daniel        VET   8.0
# 372  22               Pérez Herrer, David        VET   7.0
# 373  23           Pino Fernández, Claudia        VET  10.0
# 377  27  Villalba Carroquino, Irene Pilar        VET  10.0
#
# [270 rows x 4 columns]

# %%
actilla4 = actilla3.copy()
actilla4['Eval']=1
actilla4
# Out:
#       N                  Apellidos,Nombre Asignatura  Nota  Eval
# 3     4             Arnillas Gómez, Lucía        ARE   9.0     1
# 5     6            Bernal Bandrés, Chaime        ARE   9.0     1
# 7     8        Cárdenas Vaillant, Adriana        ARE   9.0     1
# 10   11            Gabelas Verdugo, Laura        ARE   9.0     1
# 11   12           González Blanco, Javier        ARE   9.0     1
# 12   13            González Blanco, Marta        ARE   9.0     1
# 16   17           Lafuente García, Alexia        ARE   9.0     1
# 22   23           Pino Fernández, Claudia        ARE   9.0     1
# 25   26             Vera Blánquez, Andrea        ARE   9.0     1
# 26   27  Villalba Carroquino, Irene Pilar        ARE   9.0     1
# 27    1       Alvar Hernández, José Darío         BG   8.0     1
# 28    2           Amador Bolea, Alejandro         BG   8.0     1
# 29    3              Amador Bolea, Álvaro         BG   7.0     1
# 30    4             Arnillas Gómez, Lucía         BG   6.0     1
# 31    5                 Asso Pino, Lorién         BG   9.0     1
# 32    6            Bernal Bandrés, Chaime         BG   9.0     1
# 33    7             Campos Bueno, Natalia         BG   5.0     1
# 34    8        Cárdenas Vaillant, Adriana         BG   5.0     1
# 35    9         Cremallet Aguillo, Andrea         BG  10.0     1
# 36   10             Diaconu , Diana María         BG   6.0     1
# 37   11            Gabelas Verdugo, Laura         BG   6.0     1
# 38   12           González Blanco, Javier         BG   9.0     1
# 39   13            González Blanco, Marta         BG   6.0     1
# 40   14             Gracia Bardají, Sofía         BG   7.0     1
# 41   15             Gracia Gonzalvo, Alba         BG   6.0     1
# 42   16             Julián Pérez, Claudia         BG   5.0     1
# 43   17           Lafuente García, Alexia         BG   7.0     1
# 44   18           Mariscal Beltrán, Lucía         BG   6.0     1
# 45   19         Martos Arévalo, Alejandro         BG   8.0     1
# 46   20            Pallarés Arnau, Adrián         BG   7.0     1
# ..   ..                               ...        ...   ...   ...
# 322  26             Vera Blánquez, Andrea         RC  10.0     1
# 324   1       Alvar Hernández, José Darío        TIC   9.0     1
# 325   2           Amador Bolea, Alejandro        TIC   9.0     1
# 326   3              Amador Bolea, Álvaro        TIC   9.0     1
# 332   9         Cremallet Aguillo, Andrea        TIC   8.0     1
# 333  10             Diaconu , Diana María        TIC   8.0     1
# 337  14             Gracia Bardají, Sofía        TIC   5.0     1
# 338  15             Gracia Gonzalvo, Alba        TIC   5.0     1
# 339  16             Julián Pérez, Claudia        TIC   7.0     1
# 341  18           Mariscal Beltrán, Lucía        TIC   8.0     1
# 342  19         Martos Arévalo, Alejandro        TIC   8.0     1
# 344  21             Parra Oblanca, Daniel        TIC   9.0     1
# 345  22               Pérez Herrer, David        TIC   9.0     1
# 348  25             Santiago Calvo, María        TIC   7.0     1
# 351   1       Alvar Hernández, José Darío        VET   9.0     1
# 352   2           Amador Bolea, Alejandro        VET   9.0     1
# 353   3              Amador Bolea, Álvaro        VET   6.0     1
# 355   5                 Asso Pino, Lorién        VET   9.0     1
# 356   6            Bernal Bandrés, Chaime        VET   8.0     1
# 360  10             Diaconu , Diana María        VET   6.0     1
# 362  12           González Blanco, Javier        VET   9.0     1
# 363  13            González Blanco, Marta        VET   8.0     1
# 364  14             Gracia Bardají, Sofía        VET   7.0     1
# 365  15             Gracia Gonzalvo, Alba        VET   9.0     1
# 368  18           Mariscal Beltrán, Lucía        VET   6.0     1
# 369  19         Martos Arévalo, Alejandro        VET   8.0     1
# 371  21             Parra Oblanca, Daniel        VET   8.0     1
# 372  22               Pérez Herrer, David        VET   7.0     1
# 373  23           Pino Fernández, Claudia        VET  10.0     1
# 377  27  Villalba Carroquino, Irene Pilar        VET  10.0     1
#
# [270 rows x 5 columns]

# %%
def actilla(fich='importado1', eval=1):
    fichero = fich + '.csv'
    pre_actilla = pd.read_csv(fichero, index_col=False)
    pre_actilla = pre_actilla.drop([col for col in pre_actilla if col.startswith('Unna')], axis=1)
    pre_actilla = pd.melt(pre_actilla, id_vars=["N","Apellidos,Nombre"], var_name="Asignatura", value_name="Nota")
    pre_actilla = pre_actilla[pre_actilla['Nota'].notna()]
    pre_actilla = pre_actilla.copy()
    pre_actilla['Eval'] = eval       
    return pre_actilla
    

def concatenar_actillas(inicio_nombre_fichero='importado', evaluaciones_a_incluir=1): 
    return pd.concat([actilla(inicio_nombre_fichero + str(n + 1), n + 1) for n in range(evaluaciones_a_incluir)])


evaluaciones_a_incluir = 2
inicio_nombre_fichero = 'importado'


actilla_final = concatenar_actillas(inicio_nombre_fichero,evaluaciones_a_incluir)
print(actilla_final)
actilla_final.to_csv('exportado.csv', index=False, float_format='%.0f')
# Out:
#       N                  Apellidos,Nombre Asignatura  Nota  Eval
# 3     4             Arnillas Gómez, Lucía        ARE   9.0     1
# 5     6            Bernal Bandrés, Chaime        ARE   9.0     1
# 7     8        Cárdenas Vaillant, Adriana        ARE   9.0     1
# 10   11            Gabelas Verdugo, Laura        ARE   9.0     1
# 11   12           González Blanco, Javier        ARE   9.0     1
# 12   13            González Blanco, Marta        ARE   9.0     1
# 16   17           Lafuente García, Alexia        ARE   9.0     1
# 22   23           Pino Fernández, Claudia        ARE   9.0     1
# 25   26             Vera Blánquez, Andrea        ARE   9.0     1
# 26   27  Villalba Carroquino, Irene Pilar        ARE   9.0     1
# 27    1       Alvar Hernández, José Darío         BG   8.0     1
# 28    2           Amador Bolea, Alejandro         BG   8.0     1
# 29    3              Amador Bolea, Álvaro         BG   7.0     1
# 30    4             Arnillas Gómez, Lucía         BG   6.0     1
# 31    5                 Asso Pino, Lorién         BG   9.0     1
# 32    6            Bernal Bandrés, Chaime         BG   9.0     1
# 33    7             Campos Bueno, Natalia         BG   5.0     1
# 34    8        Cárdenas Vaillant, Adriana         BG   5.0     1
# 35    9         Cremallet Aguillo, Andrea         BG  10.0     1
# 36   10             Diaconu , Diana María         BG   6.0     1
# 37   11            Gabelas Verdugo, Laura         BG   6.0     1
# 38   12           González Blanco, Javier         BG   9.0     1
# 39   13            González Blanco, Marta         BG   6.0     1
# 40   14             Gracia Bardají, Sofía         BG   7.0     1
# 41   15             Gracia Gonzalvo, Alba         BG   6.0     1
# 42   16             Julián Pérez, Claudia         BG   5.0     1
# 43   17           Lafuente García, Alexia         BG   7.0     1
# 44   18           Mariscal Beltrán, Lucía         BG   6.0     1
# 45   19         Martos Arévalo, Alejandro         BG   8.0     1
# 46   20            Pallarés Arnau, Adrián         BG   7.0     1
# ..   ..                               ...        ...   ...   ...
# 322  26             Vera Blánquez, Andrea         RC  10.0     2
# 324   1       Alvar Hernández, José Darío        TIC   9.0     2
# 325   2           Amador Bolea, Alejandro        TIC   9.0     2
# 326   3              Amador Bolea, Álvaro        TIC   9.0     2
# 332   9         Cremallet Aguillo, Andrea        TIC   8.0     2
# 333  10             Diaconu , Diana María        TIC   8.0     2
# 337  14             Gracia Bardají, Sofía        TIC   5.0     2
# 338  15             Gracia Gonzalvo, Alba        TIC   5.0     2
# 339  16             Julián Pérez, Claudia        TIC   7.0     2
# 341  18           Mariscal Beltrán, Lucía        TIC   8.0     2
# 342  19         Martos Arévalo, Alejandro        TIC   8.0     2
# 344  21             Parra Oblanca, Daniel        TIC   9.0     2
# 345  22               Pérez Herrer, David        TIC   9.0     2
# 348  25             Santiago Calvo, María        TIC   7.0     2
# 351   1       Alvar Hernández, José Darío        VET   9.0     2
# 352   2           Amador Bolea, Alejandro        VET   9.0     2
# 353   3              Amador Bolea, Álvaro        VET   6.0     2
# 355   5                 Asso Pino, Lorién        VET   9.0     2
# 356   6            Bernal Bandrés, Chaime        VET   8.0     2
# 360  10             Diaconu , Diana María        VET   6.0     2
# 362  12           González Blanco, Javier        VET   9.0     2
# 363  13            González Blanco, Marta        VET   8.0     2
# 364  14             Gracia Bardají, Sofía        VET   7.0     2
# 365  15             Gracia Gonzalvo, Alba        VET   9.0     2
# 368  18           Mariscal Beltrán, Lucía        VET   6.0     2
# 369  19         Martos Arévalo, Alejandro        VET   8.0     2
# 371  21             Parra Oblanca, Daniel        VET   8.0     2
# 372  22               Pérez Herrer, David        VET   7.0     2
# 373  23           Pino Fernández, Claudia        VET  10.0     2
# 377  27  Villalba Carroquino, Irene Pilar        VET  10.0     2
#
# [540 rows x 5 columns]

# %%
# actilla_final.groupby(['Asignatura'])['N'].count().plot()
actilla_final.groupby(['Asignatura'])['Nota'].mean().sort_values().plot(kind='bar')
