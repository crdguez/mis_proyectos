# %%
# Import all libraries needed for the tutorial

# General syntax to import specific functions in a library: 
##from (library) import (specific library function)
from pandas import DataFrame, read_csv

# General syntax to import a library but no functions: 
##import (library) as (give the library a nickname/alias)
import matplotlib.pyplot as plt
import pandas as pd #this is how I usually import pandas
import sys #only needed to determine Python version number
import matplotlib #only needed to determine Matplotlib version number
import numpy as np

# Enable inline plotting
# %matplotlib inline

# %%
actilla = pd.read_csv('importado.csv', index_col = 0)
actilla
# Out:
#                     Apellidos,Nombre  ARE  BG   CC  EF  FQ  Unnamed: 7  FR2  \
# N
# 1        Alvar Hernández, José Darío  NaN   8  NaN   5   6         NaN  7.0
# 2            Amador Bolea, Alejandro  NaN   8  NaN   6   7         NaN  6.0
# 3               Amador Bolea, Álvaro  NaN   7  NaN   5   4         NaN  7.0
# 4              Arnillas Gómez, Lucía  9.0   6  NaN   5   4         NaN  6.0
# 5                  Asso Pino, Lorién  NaN   9  8.0   5   7         NaN  8.0
# 6             Bernal Bandrés, Chaime  9.0   9  NaN   5   8         NaN  8.0
# 7              Campos Bueno, Natalia  NaN   5  7.0   5   5         NaN  5.0
# 8         Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4         NaN  7.0
# 9          Cremallet Aguillo, Andrea  NaN  10  NaN   6   4         NaN  8.0
# 10             Diaconu , Diana María  NaN   6  NaN   6   4         NaN  6.0
# 11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3         NaN  5.0
# ...

# %%
actilla.drop([col for col in actilla if col.startswith('Unna')], axis=1)
# Out:
#                     Apellidos,Nombre  ARE  BG   CC  EF  FQ  FR2  GH  IN  LE  \
# N
# 1        Alvar Hernández, José Darío  NaN   8  NaN   5   6  7.0   8   7   4
# 2            Amador Bolea, Alejandro  NaN   8  NaN   6   7  6.0   8   7   5
# 3               Amador Bolea, Álvaro  NaN   7  NaN   5   4  7.0   7   7   5
# 4              Arnillas Gómez, Lucía  9.0   6  NaN   5   4  6.0   8   6   4
# 5                  Asso Pino, Lorién  NaN   9  8.0   5   7  8.0   9   9   7
# 6             Bernal Bandrés, Chaime  9.0   9  NaN   5   8  8.0   8   9   7
# 7              Campos Bueno, Natalia  NaN   5  7.0   5   5  5.0   8   5   6
# 8         Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4  7.0   5   6   4
# 9          Cremallet Aguillo, Andrea  NaN  10  NaN   6   4  8.0   7   9   7
# 10             Diaconu , Diana María  NaN   6  NaN   6   4  6.0   5   7   4
# 11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3  5.0   7   6   5
# ...

# %%
actilla.loc[:, ~actilla.columns.str.contains('^Unnamed')]
actilla
# Out:
#                     Apellidos,Nombre  ARE  BG   CC  EF  FQ  Unnamed: 7  FR2  \
# N
# 1        Alvar Hernández, José Darío  NaN   8  NaN   5   6         NaN  7.0
# 2            Amador Bolea, Alejandro  NaN   8  NaN   6   7         NaN  6.0
# 3               Amador Bolea, Álvaro  NaN   7  NaN   5   4         NaN  7.0
# 4              Arnillas Gómez, Lucía  9.0   6  NaN   5   4         NaN  6.0
# 5                  Asso Pino, Lorién  NaN   9  8.0   5   7         NaN  8.0
# 6             Bernal Bandrés, Chaime  9.0   9  NaN   5   8         NaN  8.0
# 7              Campos Bueno, Natalia  NaN   5  7.0   5   5         NaN  5.0
# 8         Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4         NaN  7.0
# 9          Cremallet Aguillo, Andrea  NaN  10  NaN   6   4         NaN  8.0
# 10             Diaconu , Diana María  NaN   6  NaN   6   4         NaN  6.0
# 11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3         NaN  5.0
# ...

# %%
actilla.loc[:, ~actilla.columns.str.contains('^Unnamed')]
# Out:
#                     Apellidos,Nombre  ARE  BG   CC  EF  FQ  FR2  GH  IN  LE  \
# N
# 1        Alvar Hernández, José Darío  NaN   8  NaN   5   6  7.0   8   7   4
# 2            Amador Bolea, Alejandro  NaN   8  NaN   6   7  6.0   8   7   5
# 3               Amador Bolea, Álvaro  NaN   7  NaN   5   4  7.0   7   7   5
# 4              Arnillas Gómez, Lucía  9.0   6  NaN   5   4  6.0   8   6   4
# 5                  Asso Pino, Lorién  NaN   9  8.0   5   7  8.0   9   9   7
# 6             Bernal Bandrés, Chaime  9.0   9  NaN   5   8  8.0   8   9   7
# 7              Campos Bueno, Natalia  NaN   5  7.0   5   5  5.0   8   5   6
# 8         Cárdenas Vaillant, Adriana  9.0   5  NaN   4   4  7.0   5   6   4
# 9          Cremallet Aguillo, Andrea  NaN  10  NaN   6   4  8.0   7   9   7
# 10             Diaconu , Diana María  NaN   6  NaN   6   4  6.0   5   7   4
# 11            Gabelas Verdugo, Laura  9.0   6  NaN   5   3  5.0   7   6   5
# ...
